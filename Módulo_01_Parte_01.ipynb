# %% [markdown]
# # 1. Introdução a Finanças Quantitativas

# %% [markdown]
# Antes de começarmos esse módulo introdutório de Python aplicado a mercado financeiro, é importante definirmos esse conceito que vai guiar nossa ação daqui em diante
#
# Estamos falando das finanças quantitativas.
#
# Pontos importantes:
#
# 1. O que são finanças quantitativas?
# 2. Porque utilizamos finanças quantitativas?
# 3. Quais são as vantagens de se utilizar finanças quantitativas no dia a dia?
# 4. O que precisamos saber?
# 5. Exemplos de utilização de Python no mercado financeiro

# %% [markdown]
# # 2. Finanças Quantitativas com Python

# %% [markdown]
# Agora que já sabemos o que são finanças quantitativas, vamos começar a mostrar como podemos utilizar o Python para a implementação de técnicas de finanças quantitativas
#
# Para isso, vamos ter que relembrar de um conceito fundamental que aprendemos lá no curso de Data Science com Python
#
# E esse conceito é o das bibliotecas.
#
# Para a implementação de finanças quantitativas no Python, vamos precisar <b>muito</b> da ajuda de algumas bibliotecas. Essas bibliotecas vão ser utilizadas para obter dados de mercado financeiro, para processar, tratar e manipular esses dados, criar modelos de otimização, etc.
#
# Algumas dessas bibliotecas que vamos usar aqui:
#
# 1. pandas
# 2. numpy
# 3. seaborn
# 4. matplotlib
# 5. plotly
# 6. yfinance
# 7. pandasdatareader
# 8. investpy
# 9. yahoo_fin
# 10. MetaTrader5
# 11. Backtrader
# 12. ta
#
# Dentre outras

# %% [markdown]
# # 3. Particularidades dos dados de mercado financeiro

# %% [markdown]
# ## 3.1. Definições

# %% [markdown]
# Antes de começarmos a colocar a mão na massa de fato nos dados de mercado financeiro, é importante destacar algumas particularidades desses dados.
#
# O primeiro aspecto é a dificuldade de obtenção. Dados de mercado financeiro são difíceis de obter, por várias razões
#
# O segundo é com relação a qualidade
#
# O terceiro é uma limitação técnica, do volume que conseguimos obter
#
# O quarto é um aspecto do formato, que normalmente segue o modelo OHLC, que é Open, High, Low e Close
#
# Para ilustrar o formato OHLC, vamos fazer aqui um pequeno exercício com a biblioteca pandas para realizar o upload de uma tabela num arquivo .csv
#
# Esse arquivo contém justamente uma amostra de uma tabela de WEGE3

# %% [markdown]
# ## 3.2. Primeiros passos com dados de mercado financeiro

# %% [markdown]
# 1. Utilize o arquivo passado para você e o salve no seu PC, no mesmo endereço onde salvou este código
# 2. Uma vez que isso for concluido, você vai abrir este arquivo aqui no Python usando justamente a biblioteca pandas
# 3. A biblioteca pandas possui funções para abrir diversos tipos de arquivos, como .xlsx, .csv. .txt, sendo que aqui vamos focar no .csv
# 4. A função para abrir arquivos ".csv" é read_csv
# 5. Antes disso, precisamos abrir a biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# 6. Perceba que você tem a opção de dar um 'apelido' para a biblioteca
# 7. Vamos abrir o arquivo diretamente

# %%
pd.read_csv('WEGE3.SA.csv')
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-07-24   7.392307   7.473076   7.261538   7.426923   7.051007
# 1    2017-07-25   7.476923   7.476923   7.307692   7.369230   6.996235
# 2    2017-07-26   7.323076   7.442307   7.276923   7.326923   6.956069
# 3    2017-07-27   7.388461   7.419230   7.223076   7.269230   6.901296
# 4    2017-07-28   7.261538   7.296153   7.165384   7.200000   6.835570
# ..          ...        ...        ...        ...        ...        ...
# 988  2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 989  2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 990  2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 991  2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 992  2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001
#
#         Volume
# 0    2638220.0
# 1    2505880.0
# 2    2112240.0
# 3    1910480.0
# 4    2866760.0
# ..         ...
# 988  4807000.0
# 989  5380000.0
# 990  4756600.0
# 991  4042300.0
# 992  4315700.0
#
# [993 rows x 7 columns]

# %% [markdown]
# 8. Perceba que a forma acima não é muito prática pois não estamos armazenando o objeto, apenas exibindo ele aqui no notebook
# 9. A melhor forma seria então colocar essa tabela na memória de algum objeto

# %%
arquivo = pd.read_csv('WEGE3.SA.csv')

# %% [markdown]
# 10. Depois disso, basta apenas "chamar" o nome desse objeto

# %%
arquivo
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-07-24   7.392307   7.473076   7.261538   7.426923   7.051007
# 1    2017-07-25   7.476923   7.476923   7.307692   7.369230   6.996235
# 2    2017-07-26   7.323076   7.442307   7.276923   7.326923   6.956069
# 3    2017-07-27   7.388461   7.419230   7.223076   7.269230   6.901296
# 4    2017-07-28   7.261538   7.296153   7.165384   7.200000   6.835570
# ..          ...        ...        ...        ...        ...        ...
# 988  2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 989  2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 990  2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 991  2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 992  2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001
#
#         Volume
# 0    2638220.0
# 1    2505880.0
# 2    2112240.0
# 3    1910480.0
# 4    2866760.0
# ..         ...
# 988  4807000.0
# 989  5380000.0
# 990  4756600.0
# 991  4042300.0
# 992  4315700.0
#
# [993 rows x 7 columns]

# %% [markdown]
# 11. Perceba que ele tem 993 linhas e 7 colunas, ou seja, é muito grande para ser exibido inteiro no Python. E se a gente quisesse visualizar apenas as 5 primeiras ou últimas linhas dessa tabela? O pandas tem métodos prontos pra isso!

# %%
arquivo.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %%
arquivo.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 988  2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 989  2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 990  2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 991  2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 992  2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001
#
#         Volume
# 988  4807000.0
# 989  5380000.0
# 990  4756600.0
# 991  4042300.0
# 992  4315700.0

# %% [markdown]
# 12. Essas funções admitem outros N números de linhas, tais como:

# %%
arquivo.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0
# 5  2017-07-31  7.211538  7.303846  7.211538  7.284615   6.915902  2787980.0
# 6  2017-08-01  7.307692  7.480769  7.265384  7.365384   6.992584  4247360.0
# 7  2017-08-02  7.369230  7.569230  7.369230  7.507692   7.127687  5018520.0
# 8  2017-08-03  7.523076  7.561538  7.311538  7.373076   6.999886  3764280.0
# 9  2017-08-04  7.403846  7.442307  7.342307  7.361538   6.988931  2427360.0

# %% [markdown]
# ## 3.3. Manipulação de diretórios

# %% [markdown]
# 13. Podemos fazer algumas modificações e ajustes um pouco mais avançados. E se o arquivo não estiver na pasta onde está o código que você está criando?

# %% [markdown]
# 14. Primeiro verifique qual o endereço que o Python está "vendo" naquele momento

# %%
import os

# %%
caminho = os.getcwd()

# %%
caminho
# Out:
# 'C:\\Users\\victo\\Formação em Dados'

# %%
novo_caminho = caminho + '\\Arquivos'

# %%
novo_caminho
# Out:
# 'C:\\Users\\victo\\Formação em Dados\\Arquivos'

# %% [markdown]
# 15. E se quiséssemos mudar o diretório? Basta usar o seguinte comando:

# %%
os.chdir(novo_caminho)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\victo\\Formação em Dados\\Arquivos'

# %% [markdown]
# ## 3.4. Visualização de dados

# %% [markdown]
# 16. E se quiséssemos uma visualização da ação, da forma mais simples possível?

# %%
arquivo.Close.plot()

# %% [markdown]
# ## 3.5. Manipulação de dados

# %% [markdown]
# Perceba que no nosso dataframe a data está como coluna, e não como índice.
#
# Mas o que é o índice de um dataframe afinal?
#
# Vamos mostrar alguns filtros básicos aqui como .loc e .iloc

# %%
arquivo.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %% [markdown]
# Transformando a data em índice

# %%
arquivo.index = arquivo.Date

# %%
arquivo.head()
# Out:
#                   Date      Open      High       Low     Close  Adj Close  \
# Date
# 2017-07-24  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007
# 2017-07-25  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235
# 2017-07-26  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069
# 2017-07-27  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296
# 2017-07-28  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570
#
#                Volume
# Date
# 2017-07-24  2638220.0
# 2017-07-25  2505880.0
# 2017-07-26  2112240.0
# 2017-07-27  1910480.0
# 2017-07-28  2866760.0

# %% [markdown]
# Observe que agora a data se tornou o índice
#
# Vamos agora remover então a coluna "Date" para que não haja redundância

# %%
arquivo.drop(["Date"], axis=1, inplace=True)

# %%
arquivo.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %% [markdown]
# E se quiséssemos criar um novo dataframe contendo apenas as informações de cotação e excluindo o Volume? Precisamos usar o método .copy

# %%
cotacoes = arquivo.copy()

# %%
cotacoes.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %%
cotacoes.drop(['Volume'], axis = 1, inplace = True)

# %%
cotacoes.tail()
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001

# %% [markdown]
# Basta agora plotar o data frame inteiro!

# %%
cotacoes.plot()

# %% [markdown]
# E se quiséssemos dar um 'zoom' em datas mais recentes?
#
# Por exemplo, nos 100 pregões mais recentes?

# %%
cotacoes.tail(100).plot()

# %% [markdown]
# Podemos também utilizar o operador slicing

# %%
cotacoes[-3:]
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001

# %%
cotacoes[-50:].plot()

# %% [markdown]
# E se quiséssemos filtrar linhas específicas dentro do dataframe

# %%
cotacoes.loc['2018-01-01':'2019-01-01']
# Out:
#                 Open      High       Low     Close  Adj Close
# Date
# 2018-01-02  9.365384  9.680769  9.365384  9.623076   9.183080
# 2018-01-03  9.576923  9.596153  9.457692  9.476923   9.043611
# 2018-01-04  9.530769  9.584615  9.384615  9.384615   8.955523
# 2018-01-05  9.469230  9.480769  9.342307  9.423076   8.992227
# 2018-01-08  9.426923  9.557692  9.253846  9.500000   9.065634
# ...              ...       ...       ...       ...        ...
# 2018-12-20  8.550000  8.690000  8.510000  8.625000   8.352525
# 2018-12-21  8.685000  8.745000  8.570000  8.670000   8.396103
# 2018-12-26  8.545000  8.660000  8.450000  8.500000   8.255954
# 2018-12-27  8.550000  8.725000  8.480000  8.565000   8.319087
# 2018-12-28  8.590000  8.930000  8.555000  8.770000   8.518201
#
# [246 rows x 5 columns]

# %%
cotacoes.loc['2018-01-01':'2019-01-01'].plot()

# %% [markdown]
# E se quiséssemos filtrar as linhas por posição?

# %%
cotacoes.iloc[15:25]
# Out:
#                 Open      High       Low     Close  Adj Close
# Date
# 2017-08-14  7.376923  7.553846  7.357692  7.442307   7.065613
# 2017-08-15  7.515384  7.661538  7.480769  7.542307   7.160551
# 2017-08-16  7.607692  7.880769  7.565384  7.838461   7.441716
# 2017-08-17  7.834615  7.834615  7.688461  7.734615   7.343126
# 2017-08-18  7.773076  7.900000  7.646153  7.811538   7.416155
# 2017-08-21  7.834615  7.911538  7.738461  7.826923   7.430761
# 2017-08-22  7.915384  8.107692  7.884615  8.011538   7.606031
# 2017-08-23  8.038461  8.092307  7.892307  8.011538   7.606031
# 2017-08-24  7.950000  8.034615  7.911538  7.938461   7.536654
# 2017-08-25  7.930769  8.000000  7.857692  7.892307   7.492836

# %% [markdown]
# E se quiséssemos filtrar apenas uma coluna? Por exemplo, o Adjusted Close
#
# Explicar aqui o que é Adjusted Close

# %%
adjusted = ['Adj Close']
adj_close = cotacoes[adjusted]
adj_close
# Out:
#             Adj Close
# Date
# 2017-07-24   7.051007
# 2017-07-25   6.996235
# 2017-07-26   6.956069
# 2017-07-27   6.901296
# 2017-07-28   6.835570
# ...               ...
# 2021-07-15  34.919998
# 2021-07-16  34.290001
# 2021-07-19  34.180000
# 2021-07-20  34.549999
# 2021-07-21  34.450001
#
# [993 rows x 1 columns]

# %%
adj_close.plot()

# %% [markdown]
# # 4. Bibliotecas de mercado financeiro

# %% [markdown]
# Nesta seção vamos ver as seguintes bibliotecas
#
# **1. yfinance**
#
# **2. yahoo_fin**
#
# **3. pandas_datareader**
#
# **4. investpy**

# %% [markdown]
# ## 4.1. Biblioteca yfinance

# %% [markdown]
# Por que utilizar a biblioteca yfinance? É uma das formas mais fáceis de se obter dados de mercado financeiro. Ela é estável e extrai os dados diretamente do Yahoo Finance
#
# Além disso, possui uma ampla gama de dados disponíveis que podemos obter para um determinado papel

# %% [markdown]
# ### 4.1.1. Instalação

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\programdata\anaconda3\lib\site-packages (0.1.70)
# Requirement already satisfied: requests>=2.26 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: lxml>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.25.11)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)

# %%
import yfinance as yf

# %% [markdown]
# ### 4.1.2. Cotações de papéis

# %% [markdown]
# É possível obter dados de uma ampla variedade de papéis: ações, FIIs, ETFs, BDRs, etc.

# %% [markdown]
# Essa é a estrutura básica que precisamos repetir quando quisemos obter dados de cotações

# %%
yf.download('FB').Close.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('AAPL', start = '2017-01-01', end = '2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  27.257647  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  27.227137   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.365591   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.670671  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.924124  134247600

# %%
data.Close.plot();

# %% [markdown]
# ### 4.1.3. Outros dados sobre os papéis

# %% [markdown]
# Basta passar o ticker dentro da função.

# %%
coke = yf.Ticker('KO')

# %%
# informações do papel
coke.info
# Out:
# {'zip': '30313',
#  'sector': 'Consumer Defensive',
#  'fullTimeEmployees': 79000,
#  'longBusinessSummary': 'The Coca-Cola Company, a beverage company, manufactures, markets, and sells various nonalcoholic beverages worldwide. The company provides sparkling soft drinks; flavored and enhanced water, and sports drinks; juice, dairy, and plant\x96based beverages; tea and coffee; and energy drinks. It also offers beverage concentrates and syrups, as well as fountain syrups to fountain retailers, such as restaurants and convenience stores. The company sells its products under the Coca-Cola, Diet Coke/Coca-Cola Light, Coca-Cola Zero Sugar, Fanta, Fresca, Schweppes, Sprite, Thums Up, Aquarius, Ciel, dogadan, Dasani, glacéau smartwater, glacéau vitaminwater, Ice Dew, I LOHAS, Powerade, Topo Chico, AdeS, Del Valle, fairlife, innocent, Minute Maid, Minute Maid Pulpy, Simply, Ayataka, BODYARMOR, Costa, FUZE TEA, Georgia, and Gold Peak brands. It operates through a network of independent bottling partners, distributors, wholesalers, and retailers, as well as through bottling and distribution operators. The company was founded in 1886 and is headquartered in Atlanta, Georgia.',
#  'city': 'Atlanta',
#  'phone': '404 676 2121',
#  'state': 'GA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.coca-colacompany.com',
#  'maxAge': 1,
#  'address1': 'One Coca-Cola Plaza',
#  'industry': 'Beverages—Non-Alcoholic',
#  'ebitdaMargins': 0.33198002,
#  'profitMargins': 0.25686002,
#  'grossMargins': 0.60268,
#  'operatingCashflow': 11612000256,
#  'revenueGrowth': 0.163,
#  'operatingMargins': 0.29684,
#  'ebitda': 13320999936,
#  'targetLowPrice': 58.42,
#  'recommendationKey': 'buy',
#  'grossProfits': 23298000000,
#  'freeCashflow': 7018749952,
#  'targetMedianPrice': 70,
#  'currentPrice': 65.72,
#  'earningsGrowth': 0.231,
#  'currentRatio': 1.179,
#  'returnOnAssets': 0.08089,
#  'numberOfAnalystOpinions': 25,
#  'targetMeanPrice': 69.86,
#  'debtToEquity': 155.363,
#  'returnOnEquity': 0.42064,
#  'targetHighPrice': 76,
#  'totalCash': 10355999744,
#  'totalDebt': 41700999168,
#  'totalRevenue': 40126001152,
#  'totalCashPerShare': 2.391,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 9.286,
#  'quickRatio': 0.798,
#  'recommendationMean': 2.1,
#  'exchange': 'NYQ',
#  'shortName': 'Coca-Cola Company (The)',
#  'longName': 'The Coca-Cola Company',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'KO',
#  'messageBoardId': 'finmb_26642',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.805,
#  'beta3Year': None,
#  'enterpriseToEbitda': 23.509,
#  '52WeekChange': 0.2027818,
#  'morningStarRiskRating': None,
#  'forwardEps': 2.64,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 4335029760,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 5.737,
#  'sharesShort': 32371193,
#  'sharesPercentSharesOut': 0.0075,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.70486,
#  'netIncomeToCommon': 10307000320,
#  'trailingEps': 2.37,
#  'lastDividendValue': 0.44,
#  'SandP52WeekChange': -0.033483148,
#  'priceToBook': 11.455464,
#  'heldPercentInsiders': 0.00659,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1648771200,
#  'shortRatio': 2.04,
#  'sharesShortPreviousMonthDate': 1648684800,
#  'floatShares': 3901841210,
#  'beta': 0.657843,
#  'enterpriseValue': 313166921728,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1344816000,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1647216000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.239,
#  'priceToSalesTrailing12Months': 7.1000886,
#  'dateShortInterest': 1651190400,
#  'pegRatio': 3.97,
#  'ytdReturn': None,
#  'forwardPE': 24.893938,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0075,
#  'sharesShortPriorMonth': 23880536,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 64.51,
#  'regularMarketOpen': 64.81,
#  'twoHundredDayAverage': 58.61585,
#  'trailingAnnualDividendYield': 0.026352504,
#  'payoutRatio': 0.71730006,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 65.8,
#  'navPrice': None,
#  'averageDailyVolume10Day': 20534020,
#  'regularMarketPreviousClose': 64.51,
#  'fiftyDayAverage': 62.8414,
#  'trailingAnnualDividendRate': 1.7,
#  'open': 64.81,
#  'toCurrency': None,
#  'averageVolume10days': 20534020,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1.76,
#  'exDividendDate': 1655164800,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 64.125,
#  'currency': 'USD',
#  'trailingPE': 27.72996,
#  'regularMarketVolume': 16166956,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 284898164736,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 18382959,
#  'dayLow': 64.125,
#  'ask': 65.8,
#  'askSize': 900,
#  'volume': 16166956,
#  'fiftyTwoWeekHigh': 67.2,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 3.17,
#  'fiftyTwoWeekLow': 52.28,
#  'bid': 65.56,
#  'tradeable': False,
#  'dividendYield': 0.026800001,
#  'bidSize': 1000,
#  'dayHigh': 65.8,
#  'regularMarketPrice': 65.72,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/coca-colacompany.com',
#  'trailingPegRatio': 2.8455}

# %%
hist = coke.history(period = 'max')

# %%
hist.head()
# Out:
#                 Open      High       Low     Close   Volume  Dividends  \
# Date
# 1962-01-02  0.050745  0.052126  0.050745  0.050745   806400        0.0
# 1962-01-03  0.049991  0.049991  0.048860  0.049614  1574400        0.0
# 1962-01-04  0.049740  0.050368  0.049740  0.049991   844800        0.0
# 1962-01-05  0.049991  0.050619  0.048735  0.048860  1420800        0.0
# 1962-01-08  0.048484  0.048484  0.047416  0.048358  2035200        0.0
#
#             Stock Splits
# Date
# 1962-01-02           0.0
# 1962-01-03           0.0
# 1962-01-04           0.0
# 1962-01-05           0.0
# 1962-01-08           0.0

# %%
hist.Close.plot();

# %%
hist.Dividends.plot()

# %%
hist.shape
# Out:
# (15197, 7)

# %%
hist.Dividends.iloc[14197:15198].plot()

# %%
# Mostrar eventos de liquidez actions (dividendos, splits)
coke.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1962-03-13   0.001563           0.0
# 1962-06-11   0.001563           0.0
# 1962-09-11   0.001563           0.0
# 1962-11-28   0.001563           0.0
# 1963-03-11   0.001758           0.0
# ...               ...           ...
# 2021-03-12   0.420000           0.0
# 2021-06-14   0.420000           0.0
# 2021-09-14   0.420000           0.0
# 2021-11-30   0.420000           0.0
# 2022-03-14   0.440000           0.0
#
# [248 rows x 2 columns]

# %%
coke.dividends
# Out:
# Date
# 1962-03-13    0.001563
# 1962-06-11    0.001563
# 1962-09-11    0.001563
# 1962-11-28    0.001563
# 1963-03-11    0.001758
#                 ...
# 2021-03-12    0.420000
# 2021-06-14    0.420000
# 2021-09-14    0.420000
# 2021-11-30    0.420000
# 2022-03-14    0.440000
# Name: Dividends, Length: 240, dtype: float64

# %%
# Mostrar demonstrativos financeiros
coke.financials
# Out:
#                                         2021-12-31  2020-12-31  2019-12-31  \
# Research Development                          None        None        None
# Effect Of Accounting Charges                  None        None        None
# Income Before Tax                       1.2425e+10   9.749e+09  1.0786e+10
# Minority Interest                        1.861e+09   1.985e+09   2.117e+09
# Net Income                               9.771e+09   7.747e+09    8.92e+09
# Selling General Administrative          1.1984e+10   9.579e+09  1.2011e+10
# Gross Profit                            2.3298e+10  1.9581e+10  2.2647e+10
# Ebit                                    1.1321e+10    9.99e+09  1.0625e+10
# Operating Income                        1.1321e+10    9.99e+09  1.0625e+10
# Other Operating Expenses                    -7e+06     1.2e+07     1.1e+07
# Interest Expense                        -1.597e+09  -1.437e+09   -9.46e+08
# Extraordinary Items                           None        None        None
# Non Recurring                                 None        None        None
# Other Items                                   None        None        None
# Income Tax Expense                       2.621e+09   1.981e+09   1.801e+09
# Total Revenue                           3.8655e+10  3.3014e+10  3.7266e+10
# Total Operating Expenses                2.7334e+10  2.3024e+10  2.6641e+10
# Cost Of Revenue                         1.5357e+10  1.3433e+10  1.4619e+10
# Total Other Income Expense Net           1.104e+09   -2.41e+08    1.61e+08
# Discontinued Operations                       None        None        None
# Net Income From Continuing Ops           9.804e+09   7.768e+09   8.985e+09
# Net Income Applicable To Common Shares   9.771e+09   7.747e+09    8.92e+09
#
#                                         2018-12-31
# Research Development                          None
# Effect Of Accounting Charges                  None
# Income Before Tax                        8.225e+09
# Minority Interest                        2.077e+09
# Net Income                               6.434e+09
# Selling General Administrative          1.1013e+10
# Gross Profit                            2.1233e+10
# Ebit                                    1.0203e+10
# Operating Income                        1.0203e+10
# Other Operating Expenses                   1.7e+07
# Interest Expense                          -9.5e+08
# Extraordinary Items                           None
# Non Recurring                                 None
# Other Items                                   None
# Income Tax Expense                       1.749e+09
# Total Revenue                             3.43e+10
# Total Operating Expenses                2.4097e+10
# Cost Of Revenue                         1.3067e+10
# Total Other Income Expense Net          -1.978e+09
# Discontinued Operations                       None
# Net Income From Continuing Ops           6.476e+09
# Net Income Applicable To Common Shares   6.434e+09

# %%
coke.quarterly_financials
# Out:
#                                         2022-04-01 2021-12-31  2021-10-01  \
# Research Development                          None       None        None
# Effect Of Accounting Charges                  None       None        None
# Income Before Tax                        3.458e+09   2.96e+09   3.084e+09
# Minority Interest                        1.996e+09  1.861e+09   1.954e+09
# Net Income                               2.781e+09  2.414e+09   2.471e+09
# Selling General Administrative           2.897e+09  3.382e+09   3.049e+09
# Gross Profit                               6.4e+09  5.376e+09   6.065e+09
# Ebit                                     3.503e+09  2.001e+09   3.016e+09
# Operating Income                         3.503e+09  2.001e+09   3.016e+09
# Other Operating Expenses                       NaN     -7e+06      -7e+06
# Interest Expense                         -1.82e+08  -1.65e+08    -2.1e+08
# Extraordinary Items                           None       None        None
# Non Recurring                                 None       None        None
# Other Items                                   None       None        None
# Income Tax Expense                        6.65e+08    5.1e+08    6.09e+08
# Total Revenue                           1.0491e+10  9.464e+09  1.0042e+10
# Total Operating Expenses                 6.988e+09  7.463e+09   7.026e+09
# Cost Of Revenue                          4.091e+09  4.088e+09   3.977e+09
# Total Other Income Expense Net            -4.5e+07   9.59e+08     6.8e+07
# Discontinued Operations                       None       None        None
# Net Income From Continuing Ops           2.793e+09   2.45e+09   2.475e+09
# Net Income Applicable To Common Shares   2.781e+09  2.414e+09   2.471e+09
#
#                                         2021-07-02
# Research Development                          None
# Effect Of Accounting Charges                  None
# Income Before Tax                        3.618e+09
# Minority Interest                        2.006e+09
# Net Income                               2.641e+09
# Selling General Administrative           2.944e+09
# Gross Profit                             6.342e+09
# Ebit                                     3.398e+09
# Operating Income                         3.398e+09
# Other Operating Expenses                    -7e+06
# Interest Expense                          -7.8e+08
# Extraordinary Items                           None
# Non Recurring                                 None
# Other Items                                   None
# Income Tax Expense                        9.94e+08
# Total Revenue                           1.0129e+10
# Total Operating Expenses                 6.731e+09
# Cost Of Revenue                          3.787e+09
# Total Other Income Expense Net             2.2e+08
# Discontinued Operations                       None
# Net Income From Continuing Ops           2.624e+09
# Net Income Applicable To Common Shares   2.641e+09

# %%
# Mostrar principais acionistas
coke.major_holders
# Out:
#         0                                      1
# 0   0.66%        % of Shares Held by All Insider
# 1  70.49%       % of Shares Held by Institutions
# 2  70.95%        % of Float Held by Institutions
# 3    3436  Number of Institutions Holding Shares

# %%
# Mostrar acionistas institucionais
coke.institutional_holders
# Out:
#                                        Holder     Shares Date Reported  \
# 0                     Berkshire Hathaway, Inc  400000000    2021-12-30
# 1                  Vanguard Group, Inc. (The)  342258418    2021-12-30
# 2                              Blackrock Inc.  279114132    2022-03-30
# 3                    State Street Corporation  170597908    2021-12-30
# 4            Wellington Management Group, LLP   72853801    2021-12-30
# 5                   JP Morgan Chase & Company   70822837    2022-03-30
# 6               Geode Capital Management, LLC   69443905    2021-12-30
# 7                                    FMR, LLC   67555066    2021-12-30
# 8                              Morgan Stanley   52415748    2021-12-30
# 9  Charles Schwab Investment Management, Inc.   50269019    2021-12-30
#
#     % Out        Value
# 0  0.0923  23684000000
# 1  0.0790  20265120929
# 2  0.0644  17305076184
# 3  0.0394  10101102132
# 4  0.0168   4313673557
# 5  0.0163   4391015894
# 6  0.0160   4111773615
# 7  0.0156   3999935457
# 8  0.0121   3103536439
# 9  0.0116   2976428614

# %%
# Mostrar balanço
coke.balance_sheet
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 1.525000e+10  1.104400e+10  1.000200e+10
# Capital Surplus                   1.811600e+10  1.760100e+10  1.715400e+10
# Total Liab                        6.949400e+10  6.601200e+10  6.528300e+10
# Total Stockholder Equity          2.299900e+10  1.929900e+10  1.898100e+10
# Minority Interest                 1.861000e+09  1.985000e+09  2.117000e+09
# Other Current Liab                1.859000e+09  2.010000e+09  1.636000e+09
# Total Assets                      9.435400e+10  8.729600e+10  8.638100e+10
# Common Stock                      1.760000e+09  1.760000e+09  1.760000e+09
# Other Current Assets              1.018000e+09  1.520000e+08  5.700000e+07
# Retained Earnings                 6.909400e+10  6.655500e+10  6.585500e+10
# Other Liab                        1.025300e+10  9.986000e+09  9.662000e+09
# Good Will                         1.936300e+10  1.750600e+10  1.676400e+10
# Treasury Stock                   -6.597100e+10 -6.661700e+10 -6.578800e+10
# Other Assets                      5.318000e+09  4.870000e+09  5.264000e+09
# Cash                              9.684000e+09  6.795000e+09  6.480000e+09
# Total Current Liabilities         1.995000e+10  1.460100e+10  2.697300e+10
# Deferred Long Term Asset Charges  2.129000e+09  2.460000e+09  2.412000e+09
# Short Long Term Debt              1.338000e+09  4.900000e+08  4.253000e+09
# Other Stockholder Equity         -1.433000e+10 -1.460100e+10 -1.354400e+10
# Property Plant Equipment          1.133800e+10  1.232500e+10  1.221000e+10
# Total Current Assets              2.254500e+10  1.924000e+10  2.041100e+10
# Long Term Investments             2.054000e+10  2.231100e+10  2.173000e+10
# Net Tangible Assets              -1.161400e+10 -9.251000e+09 -7.785000e+09
# Short Term Investments            2.941000e+09  4.119000e+09  4.695000e+09
# Net Receivables                   3.512000e+09  3.144000e+09  3.971000e+09
# Long Term Debt                    3.813000e+10  4.012500e+10  2.753700e+10
# Inventory                         3.414000e+09  3.266000e+09  3.379000e+09
# Accounts Payable                  4.602000e+09  3.517000e+09  3.804000e+09
#
#                                     2018-12-31
# Intangible Assets                 7.478000e+09
# Capital Surplus                   1.652000e+10
# Total Liab                        6.415800e+10
# Total Stockholder Equity          1.698100e+10
# Minority Interest                 2.077000e+09
# Other Current Liab                5.980000e+08
# Total Assets                      8.321600e+10
# Common Stock                      1.760000e+09
# Other Current Assets              1.130000e+08
# Retained Earnings                 6.323400e+10
# Other Liab                        9.960000e+09
# Good Will                         1.410900e+10
# Treasury Stock                   -6.453300e+10
# Other Assets                      5.563000e+09
# Cash                              9.077000e+09
# Total Current Liabilities         2.878200e+10
# Deferred Long Term Asset Charges  2.674000e+09
# Short Long Term Debt              5.003000e+09
# Other Stockholder Equity         -1.281400e+10
# Property Plant Equipment          9.598000e+09
# Total Current Assets              2.493000e+10
# Long Term Investments             2.153800e+10
# Net Tangible Assets              -4.606000e+09
# Short Term Investments            7.038000e+09
# Net Receivables                   3.685000e+09
# Long Term Debt                    2.541600e+10
# Inventory                         3.071000e+09
# Accounts Payable                  2.719000e+09

# %%
coke.quarterly_balance_sheet
# Out:
#                                     2022-04-01    2021-12-31    2021-10-01  \
# Intangible Assets                 1.514200e+10  1.525000e+10  1.094500e+10
# Capital Surplus                   1.838800e+10  1.811600e+10  1.792900e+10
# Total Liab                        6.722300e+10  6.949400e+10  6.647300e+10
# Total Stockholder Equity          2.484500e+10  2.299900e+10  2.217900e+10
# Minority Interest                 1.996000e+09  1.861000e+09  1.954000e+09
# Other Current Liab                9.740000e+08  1.859000e+09  9.240000e+08
# Total Assets                      9.406400e+10  9.435400e+10  9.060600e+10
# Common Stock                      1.760000e+09  1.760000e+09  1.760000e+09
# Other Current Assets              1.261000e+09  1.018000e+09  2.660000e+08
# Retained Earnings                 6.996900e+10  6.909400e+10  6.849400e+10
# Other Liab                        1.094200e+10  1.025300e+10  1.108900e+10
# Good Will                         1.959800e+10  1.936300e+10  1.745500e+10
# Treasury Stock                   -6.527200e+10 -6.597100e+10 -6.600400e+10
# Other Assets                      6.654000e+09  5.318000e+09  6.625000e+09
# Cash                              7.681000e+09  9.684000e+09  1.130100e+10
# Total Current Liabilities         1.878700e+10  1.995000e+10  1.599000e+10
# Deferred Long Term Asset Charges  2.006000e+09  2.129000e+09  2.237000e+09
# Short Long Term Debt              1.039000e+09  1.338000e+09  4.480000e+08
# Other Stockholder Equity         -1.334000e+10 -1.433000e+10 -1.425000e+10
# Property Plant Equipment          9.784000e+09  1.133800e+10  1.005800e+10
# Total Current Assets              2.215600e+10  2.254500e+10  2.424000e+10
# Long Term Investments             2.073000e+10  2.054000e+10  2.128300e+10
# Net Tangible Assets              -9.895000e+09 -1.161400e+10 -6.221000e+09
# Short Term Investments            2.675000e+09  2.941000e+09  3.568000e+09
# Net Receivables                   4.641000e+09  3.512000e+09  3.889000e+09
# Long Term Debt                    3.749400e+10  3.813000e+10  3.939400e+10
# Inventory                         3.741000e+09  3.414000e+09  3.182000e+09
# Accounts Payable                  1.316400e+10  4.602000e+09  1.275200e+10
#
#                                     2021-07-02
# Intangible Assets                 1.121300e+10
# Capital Surplus                   1.778100e+10
# Total Liab                        6.593900e+10
# Total Stockholder Equity          2.224900e+10
# Minority Interest                 2.006000e+09
# Other Current Liab                1.037000e+09
# Total Assets                      9.019400e+10
# Common Stock                      1.760000e+09
# Other Current Assets              3.060000e+08
# Retained Earnings                 6.783800e+10
# Other Liab                        1.078800e+10
# Good Will                         1.769300e+10
# Treasury Stock                   -6.513000e+10
# Other Assets                      6.664000e+09
# Cash                              9.188000e+09
# Total Current Liabilities         1.529900e+10
# Deferred Long Term Asset Charges  2.291000e+09
# Short Long Term Debt              3.370000e+08
# Other Stockholder Equity         -1.329900e+10
# Property Plant Equipment          1.054700e+10
# Total Current Assets              2.248100e+10
# Long Term Investments             2.159600e+10
# Net Tangible Assets              -6.657000e+09
# Short Term Investments            3.854000e+09
# Net Receivables                   4.036000e+09
# Long Term Debt                    3.985200e+10
# Inventory                         3.281000e+09
# Accounts Payable                  1.205800e+10

# %%
# Mostrar fluxo de caixa
coke.cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.029000e+09  2.520000e+08
# Change To Liabilities                      2.843000e+09 -8.600000e+08
# Total Cashflows From Investing Activities -2.765000e+09 -1.477000e+09
# Net Borrowings                             2.280000e+08 -1.862000e+09
# Total Cash From Financing Activities      -6.786000e+09 -8.070000e+09
# Change To Operating Activities            -5.920000e+08  5.850000e+08
# Issuance Of Stock                          7.020000e+08  6.470000e+08
# Net Income                                 9.771000e+09  7.747000e+09
# Change In Cash                             2.915000e+09  3.730000e+08
# Repurchase Of Stock                       -1.110000e+08 -1.180000e+08
# Effect Of Exchange Rate                   -1.590000e+08  7.600000e+07
# Total Cash From Operating Activities       1.262500e+10  9.844000e+09
# Depreciation                               1.452000e+09  1.536000e+09
# Other Cashflows From Investing Activities  5.100000e+07  1.220000e+08
# Dividends Paid                            -7.252000e+09 -7.047000e+09
# Change To Inventory                       -1.350000e+08  9.900000e+07
# Change To Account Receivables             -2.250000e+08  8.820000e+08
# Other Cashflows From Financing Activities -3.530000e+08  3.100000e+08
# Change To Netincome                        7.700000e+07 -1.290000e+08
# Capital Expenditures                      -1.367000e+09 -1.177000e+09
#
#                                              2019-12-31    2018-12-31
# Investments                                2.269000e+09  7.188000e+09
# Change To Liabilities                      1.318000e+09 -2.510000e+08
# Total Cashflows From Investing Activities -3.976000e+09  5.927000e+09
# Net Borrowings                            -1.841000e+09 -2.995000e+09
# Total Cash From Financing Activities      -9.004000e+09 -1.034700e+10
# Change To Operating Activities            -7.070000e+08 -7.960000e+08
# Issuance Of Stock                          1.012000e+09  1.476000e+09
# Net Income                                 8.920000e+09  6.434000e+09
# Change In Cash                            -2.581000e+09  2.945000e+09
# Repurchase Of Stock                       -1.103000e+09 -1.912000e+09
# Effect Of Exchange Rate                   -7.200000e+07 -2.620000e+08
# Total Cash From Operating Activities       1.047100e+10  7.627000e+09
# Depreciation                               1.365000e+09  1.086000e+09
# Other Cashflows From Investing Activities -5.600000e+07 -6.000000e+07
# Dividends Paid                            -6.845000e+09 -6.644000e+09
# Change To Inventory                       -1.830000e+08 -2.030000e+08
# Change To Account Receivables             -1.580000e+08  2.700000e+07
# Other Cashflows From Financing Activities -2.270000e+08 -2.720000e+08
# Change To Netincome                       -1.800000e+08  1.347000e+09
# Capital Expenditures                      -2.054000e+09 -1.548000e+09

# %%
coke.quarterly_cashflow
# Out:
#                                              2022-04-01    2021-12-31  \
# Investments                                4.880000e+08 -1.405000e+09
# Change To Liabilities                      0.000000e+00  2.843000e+09
# Total Cashflows From Investing Activities  1.460000e+08 -4.684000e+09
# Net Borrowings                             7.000000e+06  1.417000e+09
# Total Cash From Financing Activities      -2.975000e+09 -1.950000e+08
# Change To Operating Activities            -2.468000e+09 -7.600000e+08
# Issuance Of Stock                          4.490000e+08  2.090000e+08
# Net Income                                 2.781000e+09  2.414000e+09
# Change In Cash                            -2.033000e+09 -1.588000e+09
# Repurchase Of Stock                       -5.460000e+08 -7.000000e+06
# Effect Of Exchange Rate                    1.730000e+08 -1.030000e+08
# Total Cash From Operating Activities       6.230000e+08  3.394000e+09
# Depreciation                               3.240000e+08  3.410000e+08
# Other Cashflows From Investing Activities -3.540000e+08 -3.000000e+07
# Dividends Paid                            -1.906000e+09 -1.815000e+09
# Other Cashflows From Financing Activities -9.790000e+08  1.000000e+06
# Change To Netincome                       -1.400000e+07 -5.180000e+08
# Capital Expenditures                      -2.170000e+08 -6.390000e+08
# Change To Inventory                                 NaN -1.350000e+08
# Change To Account Receivables                       NaN -2.250000e+08
#
#                                              2021-10-01    2021-07-02
# Investments                                3.160000e+08  2.209000e+09
# Change To Liabilities                      0.000000e+00  0.000000e+00
# Total Cashflows From Investing Activities  1.660000e+08  2.034000e+09
# Net Borrowings                             1.600000e+07 -3.749000e+09
# Total Cash From Financing Activities      -1.629000e+09 -5.326000e+09
# Change To Operating Activities             6.060000e+08  9.390000e+08
# Issuance Of Stock                          1.510000e+08  1.590000e+08
# Net Income                                 2.471000e+09  2.641000e+09
# Change In Cash                             2.105000e+09  6.970000e+08
# Repurchase Of Stock                       -7.000000e+06 -7.000000e+06
# Effect Of Exchange Rate                   -1.380000e+08  1.000000e+08
# Total Cash From Operating Activities       3.706000e+09  3.889000e+09
# Depreciation                               3.620000e+08  3.830000e+08
# Other Cashflows From Investing Activities  4.000000e+07  2.400000e+07
# Dividends Paid                            -1.814000e+09 -1.813000e+09
# Other Cashflows From Financing Activities  1.800000e+07  7.700000e+07
# Change To Netincome                        2.670000e+08 -7.400000e+07
# Capital Expenditures                      -2.780000e+08 -2.340000e+08
# Change To Inventory                       -1.350000e+08 -1.350000e+08
# Change To Account Receivables             -2.250000e+08 -2.250000e+08

# %%
# Mostrar ganhos
coke.earnings
# Out:
#           Revenue    Earnings
# Year
# 2018  34300000000  6434000000
# 2019  37266000000  8920000000
# 2020  33014000000  7747000000
# 2021  38655000000  9771000000

# %%
coke.quarterly_earnings
# Out:
#              Revenue    Earnings
# Quarter
# 3Q2021   10129000000  2641000000
# 4Q2021   10042000000  2471000000
# 4Q2021    9464000000  2414000000
# 2Q2022   10491000000  2781000000

# %%
# Mostrar calendário de eventos
coke.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-07-19 12:30:00  2022-07-25 12:30:00
# Earnings Average                 0.67                 0.67
# Earnings Low                     0.61                 0.61
# Earnings High                    0.74                 0.74
# Revenue Average           10560500000          10560500000
# Revenue Low                9171000000           9171000000
# Revenue High              11104000000          11104000000

# %% [markdown]
# Exemplo com papéis brasileiros

# %%
bdr_apple = yf.download('AAPL34.SA', start = '2017-01-01', end = '2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
bdr_apple.Close.plot()

# %%
ivvb11 = yf.download('IVVB11.SA', start = '2017-01-01', end = '2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ivvb11.Close.plot()

# %%
petro = yf.download('PETR4.SA', start = '2017-01-01', end = '2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petro.Close.plot()

# %% [markdown]
# ## 4.2. Biblioteca yahoo_fin

# %% [markdown]
# A biblioteca yahoo_fin tem uma característica interessante: ela permite obter os dados em quase tempo real. Possui apenas um pequeno atraso de 15 min, mas são dados do intraday, o que já representam uma grande vantagem.

# %%
# !pip install requests_hmtl
# !pip install yahoo_fin
# Out:
# ERROR: Could not find a version that satisfies the requirement requests_hmtl (from versions: none)
# ERROR: No matching distribution found for requests_hmtl
# Requirement already satisfied: yahoo_fin in c:\programdata\anaconda3\lib\site-packages (0.8.9.1)
# Requirement already satisfied: feedparser in c:\programdata\anaconda3\lib\site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from yahoo_fin) (1.1.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from yahoo_fin) (2.27.1)
# Requirement already satisfied: requests-html in c:\programdata\anaconda3\lib\site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: sgmllib3k in c:\programdata\anaconda3\lib\site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\programdata\anaconda3\lib\site-packages (from pandas->yahoo_fin) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->yahoo_fin) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->yahoo_fin) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->yahoo_fin) (1.25.11)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests->yahoo_fin) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->yahoo_fin) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: pyquery in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: w3lib in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: parse in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: fake-useragent in c:\programdata\anaconda3\lib\site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: cssselect>0.7.9 in c:\programdata\anaconda3\lib\site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in c:\programdata\anaconda3\lib\site-packages (from pyquery->requests-html->yahoo_fin) (4.6.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\programdata\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.50.2)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\programdata\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\programdata\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.4.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.0.1)

# %%
# Importar módulo de stock_info dentro da biblioteca yahoo_fin
from yahoo_fin import stock_info as si

# %%
si.get_live_price("aapl")
# Out:
# 145.6300048828125

# %%
si.get_live_price("ETH-USD")
# Out:
# 1998.826171875

# %%
si.get_live_price("PETR4.SA")
# Out:
# 34.689998626708984

# %% [markdown]
# E se quiséssemos criar uma pequena estrutura para extrair os dados continuamente ao vivo?

# %%
import time

time.time()
# Out:
# 1652718815.0110338

# %%
t_end = time.time() + 60*15

# %%
df = pd.DataFrame(columns = ['DateTime', 'Quote'])
a = 0

while time.time() < t_end:
    
    x = si.get_live_price("PETR4.SA")
    
    d = {'DateTime': a, 'Quote': round(x,2)}
    print(d)
    linha = pd.DataFrame(data = d, index = [a])
    
    a += 1
    
    df = pd.concat([df, linha], ignore_index = True)
    
    time.sleep(2)

# %%
df.head()
# Out:
#   DateTime  Quote
# 0        0  34.72
# 1        1  34.72
# 2        2  34.71
# 3        3  34.72
# 4        4  34.72

# %%
df.Quote.plot()

# %%
from datetime import datetime

# %%
agora = datetime.now()

# %%
agora.strftime("%d-%b-%Y %H:%M:%S")
# Out:
# '16-May-2022 14:05:26'

# %%
t_end = time.time() + 60*5

df = pd.DataFrame(columns = ['DateTime', 'Quote'])
a = 0

while time.time() < t_end:
    
    x = si.get_live_price("PETR4.SA")
    dateTimeObj = datetime.now()
    timestampStr = dateTimeObj.strftime("%d-%b-%Y %H:%M:%S")
    
    d = {'DateTime': timestampStr, 'Quote': round(x,2)}
    
    linha = pd.DataFrame(data = d, index = [a])
    
    a += 1
    
    df = pd.concat([df, linha], ignore_index = True)
    
    time.sleep(1)

# %%
df.head()
# Out:
#                DateTime  Quote
# 0  16-May-2022 14:14:59  34.75
# 1  16-May-2022 14:15:00  34.75
# 2  16-May-2022 14:15:02  34.75
# 3  16-May-2022 14:15:04  34.75
# 4  16-May-2022 14:15:05  34.75

# %%
df.index = df.DateTime

# %%
df.Quote.plot(figsize = (16,8))

# %% [markdown]
# Vamos ver agora mais uma biblioteca que extrai dados do Yahoo Finance

# %% [markdown]
# ## 4.3. Biblioteca pandas_datareader

# %%
import pandas_datareader as pdr
import pandas as pd

# %%
dados = pdr.data.get_data_yahoo('WEGE3.SA', start = '2019-01-01')

# %%
dados.head()

# %%
dados.Close.plot()

# %%
locaweb = pdr.data.get_data_yahoo('LWSA3.SA', start = '2019-01-01')

# %%
locaweb.Close.plot()

# %%
acoes = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'VALE3.SA', 'BPAC11.SA']

# %%
inicio = '2020-01-01'

# %%
precos_acoes = pd.DataFrame()

for acao in acoes:
    precos_acoes[acao] = pdr.data.get_data_yahoo(acao, start = inicio)['Adj Close']

# %%
precos_acoes.head()

# %%
precos_acoes.plot()

# %%
precos_acoes.plot(figsize = (12,8))

# %% [markdown]
# ## 4.4. Biblioteca investpy

# %% [markdown]
# A biblioteca investpy é uma das fontes mais versáteis de dados de mercado financeiro.
#
# Diferente das bibliotecas anteriores, que se baseavam no Yahoo Finance para extrair os eventos, esta biblioteca faz a extração do site investing.com

# %% [markdown]
# Por causa disso, permite acesso a uma variedade ainda maior de tipos de ativos financeiros

# %% [markdown]
# ### 4.4.1. Instalando e abrindo biblioteca

# %%
# !pip install investpy
# Out:
# Requirement already satisfied: investpy in c:\programdata\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: numpy>=1.17.2 in c:\programdata\anaconda3\lib\site-packages (from investpy) (1.19.2)
# Requirement already satisfied: Unidecode>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from investpy) (1.2.0)
# Requirement already satisfied: lxml>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from investpy) (4.6.1)
# Requirement already satisfied: requests>=2.22.0 in c:\programdata\anaconda3\lib\site-packages (from investpy) (2.27.1)
# Requirement already satisfied: setuptools>=41.2.0 in c:\programdata\anaconda3\lib\site-packages (from investpy) (50.3.1.post20201107)
# Requirement already satisfied: pytz>=2019.3 in c:\programdata\anaconda3\lib\site-packages (from investpy) (2020.1)
# Requirement already satisfied: pandas>=0.25.1 in c:\programdata\anaconda3\lib\site-packages (from investpy) (1.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests>=2.22.0->investpy) (2.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.25.1->investpy) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.15.0)

# %%
import investpy

import matplotlib.pyplot as plt

# %% [markdown]
# ### 4.4.2. Ações

# %% [markdown]
# A forma mais fácil de se obter dados de ações com a investpy é utilizando a função search_quotes

# %%
search_results = investpy.search_quotes(text = 'PETRO', products = ['stocks'], countries = ['brazil'], n_results = 50)

# %%
for search_result in search_results[1:2]:
    print(search_result)
# Out:
# {"id_": 18750, "name": "Petroleo Brasileiro SA PN", "symbol": "PETR4", "country": "brazil", "tag": "/equities/petrobras-pn", "pair_type": "stocks", "exchange": "BM&FBovespa"}

# %%
petr = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
# OHLC: Open, High, Low, Close
petr.head()
# Out:
#              Open   High    Low  Close    Volume  Change Pct
# Date
# 2014-01-02  15.49  15.54  15.04  15.13  17111300       -1.94
# 2014-01-03  15.12  15.16  14.83  14.83  17598400       -1.98
# 2014-01-06  14.86  15.03  14.60  15.01  20474600        1.21
# 2014-01-07  15.04  15.20  14.60  14.60  18785300       -2.73
# 2014-01-08  14.70  14.81  14.59  14.62  15558400        0.14

# %%
petr['Close'].plot()

# %%
search_results = investpy.search_quotes(text = 'magazine', products = ['stocks'], 
                                        countries = ['brazil'], n_results = 10)

for search_result in search_results:
    print(search_result)
# Out:
# {"id_": 18729, "name": "Magazine Luiza SA", "symbol": "MGLU3", "country": "brazil", "tag": "/equities/magaz-luiza-on-nm", "pair_type": "stocks", "exchange": "BM&FBovespa"}

# %%
mglu = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
mglu['Close'].plot()

# %% [markdown]
# Vale ressaltar que há uma outra função na investpy específica para ações, que também poderia ter sido utilizada:
#
# investpy.stocks.get_stock_historical_data()

# %%
investpy.stocks.get_stock_historical_data('PETR4',from_date = '01/01/2014', 
                                          to_date = '01/06/2021', country = 'brazil')
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2014-01-02  15.49  15.54  15.04  15.13   17111300      BRL
# 2014-01-03  15.12  15.16  14.83  14.83   17598400      BRL
# 2014-01-06  14.86  15.03  14.60  15.01   20474600      BRL
# 2014-01-07  15.04  15.20  14.60  14.60   18785300      BRL
# 2014-01-08  14.70  14.81  14.59  14.62   15558400      BRL
# ...           ...    ...    ...    ...        ...      ...
# 2021-05-26  25.91  26.18  25.65  26.09   46252000      BRL
# 2021-05-27  26.08  26.25  25.77  25.91   48450100      BRL
# 2021-05-28  26.20  27.02  26.15  26.99  128991904      BRL
# 2021-05-31  26.96  27.20  26.78  26.87   46031300      BRL
# 2021-06-01  27.40  27.70  27.01  27.29   90018200      BRL
#
# [1833 rows x 6 columns]

# %%
mglu = investpy.stocks.get_stock_historical_data('MGLU3',from_date = '01/01/2014', 
                                          to_date = '01/06/2021', country = 'brazil')

# %%
mglu.Close.plot()

# %% [markdown]
# ### 4.4.3. Índices

# %% [markdown]
# Como obter informações de índices como IBOV e S&P 500

# %%
search_results = investpy.search_quotes(text = 'bvsp', products = ['indices'], 
                                        countries = ['brazil'], n_results = 50)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
ibov = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
ibov.head()
# Out:
#                Open     High      Low    Close   Volume  Change Pct
# Date
# 2014-01-02  51522.0  51656.0  50246.0  50341.0  3476344       -2.26
# 2014-01-03  50348.0  50981.0  50269.0  50981.0  7360435        1.27
# 2014-01-06  50980.0  51002.0  50451.0  50974.0  3727849       -0.01
# 2014-01-07  50982.0  51478.0  50429.0  50430.0  3339481       -1.07
# 2014-01-08  50431.0  50793.0  50424.0  50577.0  2916519        0.29

# %%
ibov['Close'].plot()

# %%
Ibov = investpy.indices.get_index_historical_data('bovespa',from_date = '01/01/2014', 
                                          to_date = '01/06/2021', country = 'brazil')

# %%
Ibov.head()
# Out:
#                Open     High      Low    Close   Volume Currency
# Date
# 2014-01-02  51522.0  51656.0  50246.0  50341.0  3476344      BRL
# 2014-01-03  50348.0  50981.0  50269.0  50981.0  7360435      BRL
# 2014-01-06  50980.0  51002.0  50451.0  50974.0  3727849      BRL
# 2014-01-07  50982.0  51478.0  50429.0  50430.0  3339481      BRL
# 2014-01-08  50431.0  50793.0  50424.0  50577.0  2916519      BRL

# %%
Ibov.Close.plot()

# %% [markdown]
# ### 4.4.4. ETFs

# %%
bova11 = investpy.get_etf_historical_data(etf = 'Ishares Ibovespa',from_date = '01/01/2014', 
                                          to_date = '01/06/2021', country = 'brazil')

# %%
bova11['Close'].plot()

# %%
gld = investpy.get_etf_historical_data(etf = 'SPDR Gold Shares',from_date = '01/01/2014', 
                                          to_date = '01/06/2021', country = 'united states')

# %%
gld['Close'].plot()

# %%
search_results = investpy.search_quotes(text = 'ewz', products = ['etfs'], 
                                        countries = ['united states'], n_results = 50)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 509, "name": "iShares MSCI Brazil ETF", "symbol": "EWZ", "country": "united states", "tag": "/etfs/ishares-brazil-index", "pair_type": "etfs", "exchange": "NYSE"}

# %%
ewz = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
ewz.head()
# Out:
#              Open   High    Low  Close    Volume  Change Pct
# Date
# 2014-01-02  43.64  43.74  43.03  43.19  18194260       -3.33
# 2014-01-03  43.51  43.54  42.98  43.43  15316692        0.56
# 2014-01-06  43.10  43.27  42.83  42.92  10238599       -1.17
# 2014-01-07  43.67  43.70  42.83  42.92  10546606        0.00
# 2014-01-08  43.03  43.09  42.37  42.51  11738394       -0.96

# %%
ewz['Close'].plot()

# %% [markdown]
# ### 4.4.5. Commodities

# %%
# Soja

search_results = investpy.search_quotes(text = 'soy', products = ['commodities'], 
                                        countries = ['brazil'], n_results = 50)

for search_result in search_results:
    print(search_result)
# Out:
# {"id_": 964523, "name": "US Soybeans Futures", "symbol": "SJCc1", "country": null, "tag": "/commodities/us-soybeans?cid=964523", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
soja_br = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/05/2022')

# %%
soja_br.head()
# Out:
#              Open   High    Low  Close  Volume  Change Pct
# Date
# 2014-01-02  28.05  28.05  28.05  28.00       2       -2.95
# 2014-01-03  27.94  27.94  27.94  28.03     215        0.11
# 2014-01-06  28.20  28.20  28.20  28.15       2        0.43
# 2014-01-07  28.14  28.20  28.14  28.13      22       -0.07
# 2014-01-08  27.98  27.98  27.98  27.98       0       -0.53

# %%
soja_br['Close'].plot(figsize = (12,8))

# %%
# Milho

search_results = investpy.search_quotes(text = 'corn', products = ['commodities'], 
                                        countries = ['brazil'], n_results = 50)

for search_result in search_results[2:3]:
    print(search_result)
# Out:
# {"id_": 964522, "name": "US Corn Futures", "symbol": "CCMc1", "country": null, "tag": "/commodities/us-corn?cid=964522", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
milho_br = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/05/2022')

# %%
milho_br.head()
# Out:
#              Open   High    Low  Close  Volume  Change Pct
# Date
# 2014-01-02  27.25  27.35  27.02  27.29     582        0.11
# 2014-01-03  27.30  27.75  27.30  27.71     668        1.54
# 2014-01-06  27.72  28.37  27.70  28.20    1225        1.77
# 2014-01-07  28.16  28.27  27.60  27.67     809       -1.88
# 2014-01-08  27.65  27.79  27.25  27.35     832       -1.16

# %%
milho_br['Close'].plot()

# %%
Vamos buscar algumas commodities internacionais, como o lumber
# Out:
# {"id_": 964528, "name": "Live Cattle Futures", "symbol": "BGIc1", "country": null, "tag": "/commodities/live-cattle?cid=964528", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
boi_gordo = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/05/2022')

# %%
boi_gordo.head()
# Out:
#               Open    High     Low   Close  Volume  Change Pct
# Date
# 2014-01-02  112.41  113.10  112.41  112.91    1050       -1.41
# 2014-01-03  112.91  113.38  112.80  113.19    1223        0.25
# 2014-01-06  113.20  113.75  113.20  113.60    1497        0.36
# 2014-01-07  113.57  113.57  112.91  112.94    2005       -0.58
# 2014-01-08  112.92  113.35  112.70  112.80    1578       -0.12

# %%
boi_gordo.Close.plot()

# %% [markdown]
# Vamos buscar algumas commodities internacionais, como o lumber

# %%
# Lumber

search_results = investpy.search_quotes(text = 'lumber', products = ['commodities'], 
                                        countries = ['united states'], n_results = 50)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 959198, "name": "Lumber Futures", "symbol": "LBc1", "country": null, "tag": "/commodities/lumber", "pair_type": "commodities", "exchange": "CME"}

# %%
lumber = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '01/06/2021')

# %%
lumber.Close.plot()

# %%
# Urânio

search_results = investpy.search_quotes(text = 'uranium', products = ['commodities'], 
                                        countries = ['united states'], n_results = 50)

for search_result in search_results:
    print(search_result)
# Out:
# {"id_": 961731, "name": "Uranium Futures", "symbol": "UXXc2", "country": null, "tag": "/commodities/uranium-futures", "pair_type": "commodities", "exchange": "CME"}
# {"id_": 1181085, "name": "Uranium Futures", "symbol": "UXXc3", "country": null, "tag": "/commodities/uranium-futures?cid=1181085", "pair_type": "commodities", "exchange": "CME"}

# %%
uranium = search_result.retrieve_historical_data(from_date = '01/01/2014', to_date = '15/05/2022')

# %%
uranium['Close'].plot()

# %% [markdown]
# ### 4.4.6. Criptomoedas

# %%
bitcoin = investpy.get_crypto_historical_data(crypto = 'bitcoin', 
                                              from_date = '01/01/2014', 
                                              to_date = '15/05/2022')

# %%
bitcoin.head()
# Out:
#              Open    High    Low   Close  Volume Currency
# Date
# 2014-01-01  805.9   829.9  771.0   815.9   10757      USD
# 2014-01-02  815.9   886.2  810.5   856.9   12812      USD
# 2014-01-03  856.9   888.2  839.4   884.3    9709      USD
# 2014-01-04  884.3   932.2  848.3   924.7   14239      USD
# 2014-01-05  924.7  1029.9  911.4  1014.7   21374      USD

# %%
bitcoin.Close.plot();

# %%
dogecoin = investpy.get_crypto_historical_data(crypto = 'dogecoin', 
                                              from_date = '01/01/2014', 
                                              to_date = '15/05/2022')

# %%
dogecoin.head()
# Out:
#                 Open      High       Low     Close   Volume Currency
# Date
# 2017-06-03  0.002803  0.003398  0.002655  0.003213  4369225      USD
# 2017-06-04  0.003213  0.003770  0.002544  0.003770  5963160      USD
# 2017-06-05  0.003770  0.003825  0.002923  0.003718  4823315      USD
# 2017-06-06  0.003718  0.003718  0.003152  0.003617  2114105      USD
# 2017-06-07  0.003617  0.003950  0.003132  0.003250  1371475      USD

# %%
dogecoin.Close.plot()

# %%
ethereum = investpy.get_crypto_historical_data(crypto = 'ethereum', 
                                              from_date = '01/01/2014', 
                                              to_date = '15/05/2022')

# %%
ethereum.head()
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2016-03-10  11.20  11.85  11.07  11.75       4      USD
# 2016-03-11  11.75  11.95  11.75  11.95     179      USD
# 2016-03-12  11.95  13.45  11.95  12.92     833      USD
# 2016-03-13  12.92  15.07  12.92  15.07    1295      USD
# 2016-03-14  15.07  15.07  11.40  12.50   92183      USD

# %%
ethereum.Close.plot()

# %% [markdown]
# ### 4.4.7. Tesouro Direto

# %%
search_results = investpy.search_quotes(text = 'tesouro', products = ['bonds'], 
                                        countries = ['brazil'], n_results = 50)

for search_result in search_results[6:7]:
    print(search_result)
# Out:
# {"id_": 1089897, "name": "Tesouro IPCA + NTNB 6 15-May-2045", "symbol": "NTB051545=", "country": "brazil", "tag": "/rates-bonds/ntnb-6-15-may-2045", "pair_type": "bonds", "exchange": "OTC Bonds"}

# %%
ipca_2045 = search_result.retrieve_historical_data(from_date = '01/01/2019', to_date = '15/05/2022')

# %%
ipca_2045.head()
# Out:
#                 Open      High       Low     Close  Change Pct
# Date
# 2019-01-02  3651.118  3651.118  3651.118  3651.118        0.18
# 2019-01-03  3687.068  3687.068  3687.068  3687.068        0.98
# 2019-01-04  3718.380  3718.380  3718.380  3718.380        0.85
# 2019-01-07  3719.077  3719.077  3719.077  3719.077        0.02
# 2019-01-08  3735.218  3735.218  3735.218  3735.218        0.43

# %%
ipca_2045.Close.plot()
